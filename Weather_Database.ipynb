# %%
#Import dependencies
import pandas as np
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)

cities
# Out:
# ['rikitea',
#  'hobart',
#  'quatre cocos',
#  'port alfred',
#  'arraial do cabo',
#  'puerto ayora',
#  'ballina',
#  'khatanga',
#  'punta arenas',
#  'honningsvag',
#  'nalut',
#  'bredasdorp',
#  'deputatskiy',
#  'hualmay',
#  'lewisburg',
#  'port elizabeth',
#  'albany',
#  'yellowknife',
#  'grindavik',
#  'castro',
#  'juba',
#  'pecos',
#  'ushuaia',
#  'abu dhabi',
#  'taolanaro',
#  'santa maria',
#  'porto novo',
#  'kodiak',
#  'port blair',
#  'barrow',
#  'kloulklubed',
#  'karasburg',
#  'port-gentil',
#  'kamaishi',
#  'amnat charoen',
#  'cabo san lucas',
#  'vaini',
#  'new norfolk',
#  'meulaboh',
#  'puerto quijarro',
#  'sept-iles',
#  'gusau',
#  'busselton',
#  'itaituba',
#  'lebu',
#  'kapaa',
#  'saint-joseph',
#  'mar del plata',
#  'riyadh',
#  'mataura',
#  'bluff',
#  'clyde river',
#  'port lincoln',
#  'ordzhonikidze',
#  'greece',
#  'havoysund',
#  'enumclaw',
#  'avarua',
#  'barentsburg',
#  'skjervoy',
#  'raudeberg',
#  'kirakira',
#  'thompson',
#  'norton',
#  'anadyr',
#  'baisha',
#  'iqaluit',
#  'mitsamiouli',
#  'jamestown',
#  'linjiang',
#  'saint george',
#  'irbeyskoye',
#  'tulum',
#  'zhangjiakou',
#  'pevek',
#  'hermanus',
#  'denpasar',
#  'mys shmidta',
#  'victoria',
#  'ca mau',
#  'gigmoto',
#  'chokurdakh',
#  'taltal',
#  'tiksi',
#  'louisbourg',
#  'upernavik',
#  'bengkulu',
#  'qaanaaq',
#  'gravdal',
#  'mahebourg',
#  'henties bay',
#  'nikolskoye',
#  'pisco',
#  'deloraine',
#  'nuuk',
#  'lavrentiya',
#  'osoyoos',
#  'san cristobal',
#  'sentyabrskiy',
#  'jacareacanga',
#  'salalah',
#  'leiva',
#  'bathsheba',
#  'escanaba',
#  'cape town',
#  'kaitangata',
#  'agadez',
#  'ketchikan',
#  'morehead',
#  'saint-pierre',
#  'husavik',
#  'naze',
#  'hilo',
#  'oshikango',
#  'port hardy',
#  'zhangye',
#  'esperance',
#  'karatau',
#  'saskylakh',
#  'moree',
#  'pangai',
#  'akdepe',
#  'cochrane',
#  'saint-augustin',
#  'victor harbor',
#  'sao felix do xingu',
#  'sechura',
#  'illoqqortoormiut',
#  'vila franca do campo',
#  'amderma',
#  'grand island',
#  'kavaratti',
#  'klaksvik',
#  'hasaki',
#  'fortuna',
#  'tumannyy',
#  'gobabis',
#  'katsuura',
#  'taoudenni',
#  'bethel',
#  'coihueco',
#  'svetlogorsk',
#  'broken hill',
#  'kalevala',
#  'benghazi',
#  'tuktoyaktuk',
#  'olafsvik',
#  'constitucion',
#  'severo-kurilsk',
#  'atoyatempan',
#  'zyryanka',
#  'grong',
#  'kluang',
#  'port keats',
#  'jiangyan',
#  'lake cowichan',
#  'chamba',
#  'bambous virieux',
#  'karamea',
#  'longyearbyen',
#  'astoria',
#  'vastseliina',
#  'port-de-paix',
#  'mehamn',
#  'pemba',
#  'westpunt',
#  'waipawa',
#  'harer',
#  'tuatapere',
#  'seoul',
#  'cabedelo',
#  'seymchan',
#  'new baltimore',
#  'verkhnyaya toyma',
#  'waldoboro',
#  'tasiilaq',
#  'provideniya',
#  'bor',
#  'itacoatiara',
#  'narsaq',
#  'georgetown',
#  'vila',
#  'caravelas',
#  'taburi',
#  'smithers',
#  'kailua',
#  'karaul',
#  'atuona',
#  'adamas',
#  'makakilo city',
#  'padang',
#  'hambantota',
#  'palana',
#  'yumen',
#  'wanning',
#  'carnarvon',
#  'znamenskoye',
#  'grenada',
#  'lagoa',
#  'sabang',
#  'dalby',
#  'porbandar',
#  'attawapiskat',
#  'novyy karachay',
#  'saint-francois',
#  'rocha',
#  'butaritari',
#  'kenora',
#  'bandiagara',
#  'saint-philippe',
#  'puro',
#  'tarudant',
#  'bur gabo',
#  'westport',
#  'sao filipe',
#  'apaseo el grande',
#  'hithadhoo',
#  'vanavara',
#  'calvinia',
#  'xghajra',
#  'fukue',
#  'taree',
#  'gayny',
#  'akcakoca',
#  'chardara',
#  'myaundzha',
#  'bilma',
#  'gladstone',
#  'takoradi',
#  'constantine',
#  'osa',
#  'mount gambier',
#  'vila velha',
#  'vaitupu',
#  'aqtobe',
#  'cidreira',
#  'ribeira grande',
#  'kedrovka',
#  'evensk',
#  'sibolga',
#  'nizhneyansk',
#  'brae',
#  'gwadar',
#  'micheweni',
#  'watsa',
#  'danielskuil',
#  'teahupoo',
#  'saldanha',
#  'airai',
#  'kaseda',
#  'kristiansund',
#  'sayyan',
#  'himora',
#  'saint-michel-des-saints',
#  'aklavik',
#  'marawi',
#  'arona',
#  'kamenskoye',
#  'paamiut',
#  'kesennuma',
#  'isangel',
#  'sakakah',
#  'chatra',
#  'chuy',
#  'tsihombe',
#  'dillon',
#  'show low',
#  'mackay',
#  'ratnapura',
#  'sakaiminato',
#  'san quintin',
#  'sarakhs',
#  'palmer',
#  'xichang',
#  'bongandanga',
#  'kalianget',
#  'sioux lookout',
#  'ponta do sol',
#  'samarai',
#  'stoyba',
#  'gimli',
#  'inhambane',
#  'itarema',
#  'cockburn town',
#  'kon tum',
#  'alamos',
#  'bilibino',
#  'jatiroto',
#  'san patricio',
#  'mitu',
#  'tevaitoa',
#  'batemans bay',
#  'tucupita',
#  'port augusta',
#  'dhemaji',
#  'faanui',
#  'gari',
#  'oksfjord',
#  'iralaya',
#  'sitka',
#  'kaa-khem',
#  'nanortalik',
#  'codrington',
#  'santo antonio do amparo',
#  'ussel',
#  'sapele',
#  'sovetskiy',
#  'laguna',
#  'darhan',
#  'north bend',
#  'sergeyevka',
#  'ormara',
#  'okhotsk',
#  'talnakh',
#  'dekar',
#  'kieta',
#  'zhigansk',
#  'flinders',
#  'egvekinot',
#  'akyab',
#  'mouzakion',
#  'haines junction',
#  'tazovskiy',
#  'chandpur',
#  'beira',
#  'mugur-aksy',
#  'minnedosa',
#  'roald',
#  'yar-sale',
#  'geraldton',
#  'baherden',
#  'buala',
#  'usta muhammad',
#  'san lawrenz',
#  'cooma',
#  'yeniseysk',
#  'lolua',
#  'souillac',
#  'buchach',
#  'kholodnyy',
#  'kolga',
#  'shima',
#  'twentynine palms',
#  'key largo',
#  'itoman',
#  'warrensburg',
#  'ulladulla',
#  'tunxi',
#  'malindi',
#  'la ronge',
#  'formosa do rio preto',
#  'tukrah',
#  'salinopolis',
#  'herat',
#  'puerto baquerizo moreno',
#  'ilulissat',
#  'morgantown',
#  'peace river',
#  'fare',
#  'pangnirtung',
#  'do gonbadan',
#  'eaton socon',
#  'saint anthony',
#  'aksarka',
#  'tabuk',
#  'shieli',
#  'east london',
#  'cayenne',
#  'shingu',
#  'ventspils',
#  'baykit',
#  'touros',
#  'madaba',
#  'tocopilla',
#  'havre-saint-pierre',
#  'belmonte',
#  'tual',
#  'syracuse',
#  'kahului',
#  'gushikawa',
#  'toliary',
#  'palabuhanratu',
#  'hofn',
#  'marcona',
#  'pascagoula',
#  'tambun',
#  'nurlat',
#  'yertarskiy',
#  'coquimbo',
#  'kitami',
#  'bloomingdale',
#  'aitape',
#  'quibor',
#  'tir pol',
#  'baruun-urt',
#  'dikson',
#  'sao jose da coroa grande',
#  'conde',
#  'namatanai',
#  'bolungarvik',
#  'dargaville',
#  'kango',
#  'alofi',
#  'guerrero negro',
#  'udachnyy',
#  'anshun',
#  'gotsu',
#  'chara',
#  'kaka',
#  'tougue',
#  'yirol',
#  'barcelos',
#  'inongo',
#  'ngukurr',
#  'nouadhibou',
#  'iwata',
#  'sao joao da barra',
#  'waikuku',
#  'lorengau',
#  'maldonado',
#  'mount isa',
#  'leua',
#  'mattru',
#  'omboue',
#  'torun',
#  'dunedin',
#  'oda',
#  'fereydun kenar',
#  'kudeyevskiy',
#  'lata',
#  'fairbanks',
#  'noyabrsk',
#  'tautira',
#  'nikel',
#  'chicama',
#  'bata',
#  'bang racham',
#  'belushya guba',
#  'college',
#  'novoagansk',
#  'half moon bay',
#  'ozerne',
#  'abeokuta',
#  'la crosse',
#  'vicuna',
#  'ola',
#  'novikovo',
#  'kutum',
#  'babanusah',
#  'coihaique',
#  'marzuq',
#  'pachora',
#  'tapaua',
#  'kpandae',
#  'tekeli',
#  'grand baie',
#  'inirida',
#  'asfi',
#  'nantucket',
#  'abnub',
#  'lovozero',
#  'guanica',
#  'hami',
#  'karratha',
#  'santa isabel do rio negro',
#  'hvittingfoss',
#  'pochutla',
#  'ngunguru',
#  'dicamay',
#  'rosetta',
#  'khuzhir',
#  'namibe',
#  'lavras',
#  'norman wells',
#  'sibu',
#  'stokmarknes',
#  'vladimiro-aleksandrovskoye',
#  'balykshi',
#  'chapais',
#  'verkhoyansk',
#  'kyren',
#  'kinna',
#  'yunjinghong',
#  'samusu',
#  'muyezerskiy',
#  'shelburne',
#  'san rafael del sur',
#  'olot',
#  'qaqortoq',
#  'oistins',
#  'lakes entrance',
#  'boende',
#  'talcahuano',
#  'harper',
#  'pimentel',
#  'lompoc',
#  'iquitos',
#  'kishi',
#  'lashio',
#  'parabel',
#  'san lorenzo',
#  'richfield',
#  'alice springs',
#  'dumas',
#  'saleaula',
#  'monroe',
#  'novyy urengoy',
#  'hampton',
#  'cabra',
#  'san juan',
#  'necochea',
#  'ayagoz',
#  'vardo',
#  'ifakara',
#  'green river',
#  'krasnoselkup',
#  'poum',
#  'baker city',
#  'nemuro',
#  'krasnomayskiy',
#  'ambodifototra',
#  'torbay',
#  'kalat',
#  'dhanera',
#  'marquette',
#  'ulaangom',
#  'mena',
#  'metkovic',
#  'kankon',
#  'christchurch',
#  'kyzyl-suu',
#  'stantsionno-oyashinskiy',
#  'cheuskiny',
#  'la palma',
#  'kenai',
#  'healesville',
#  'hammerfest',
#  'namwala',
#  'kautokeino',
#  'solano',
#  'tete',
#  'ojinaga',
#  'honiara',
#  'artyk',
#  'tigil',
#  'mecca',
#  'ascension',
#  'warrington',
#  'jiroft',
#  'pingzhuang',
#  'atikokan',
#  'komsomolskiy',
#  'naryan-mar',
#  'charlottetown',
#  'avera',
#  'neubiberg',
#  'sorland',
#  'hovd',
#  'los llanos de aridane',
#  'luanda',
#  'xingcheng',
#  'ukiah',
#  'pagsabangan',
#  'bomet',
#  'mayo',
#  'north battleford',
#  'petauke',
#  'plyussa',
#  'mangrol',
#  'boyolangu',
#  'novosysoyevka',
#  'valparaiso',
#  'carbondale',
#  'bargal',
#  'natal',
#  'mocambique',
#  'kurilsk',
#  'ust-kamchatsk',
#  'sorong',
#  'romitan',
#  'pacific grove',
#  'awbari',
#  'eunice',
#  'gulshat',
#  'te anau',
#  'ginda',
#  'pokhara',
#  'viesca',
#  'broome',
#  'kwinana',
#  'lichuan',
#  'santa luzia',
#  'baniachang',
#  'tolbazy',
#  'mogadishu',
#  'atar',
#  'blairmore',
#  'turinsk',
#  'yarmouth',
#  'viedma',
#  'kilimatinde',
#  'reserva',
#  'yuancheng',
#  'launceston',
#  'mareeba',
#  'windhoek',
#  'hun',
#  'hudiksvall',
#  'grand river south east',
#  'phan thiet',
#  'umzimvubu',
#  'zhaotong',
#  'vondrozo',
#  'leningradskiy',
#  'hervey bay',
#  'paita',
#  'kruisfontein',
#  'korla',
#  'vallenar',
#  'grand gaube',
#  'mahibadhoo',
#  'senanga',
#  'vao',
#  'umea',
#  'sibi',
#  'aripuana',
#  'chabahar',
#  'tuapse',
#  'kvarkeno',
#  'bulgan',
#  'sajanan',
#  'meyungs',
#  'lamu',
#  'kavieng',
#  'bhainsa',
#  'tairua',
#  'bonfim',
#  'loubomo',
#  'miri',
#  'coacoyul',
#  'torzhok',
#  'barabinsk',
#  'labuhan',
#  'qabaqcol',
#  'usakos',
#  'stafford',
#  'santiago de cuba',
#  'batagay-alyta',
#  'palauig',
#  'avallon',
#  'nambucca heads',
#  'tabiauea',
#  'ozernovskiy',
#  'tessalit',
#  'lahat',
#  'predivinsk',
#  'palafrugell',
#  'kimbe',
#  'koboldo',
#  'nanakuli',
#  'agua dulce',
#  'itambe',
#  'bonavista',
#  'borogontsy',
#  'morant bay',
#  'byron bay',
#  'sinnamary',
#  'phuket',
#  'laizhou',
#  'mnogovershinnyy',
#  'branesti',
#  'riosucio',
#  'samur',
#  'puerto cabezas',
#  'manono',
#  'mishelevka',
#  'albuquerque',
#  'gorontalo',
#  'tchaourou',
#  'sisimiut',
#  'poole',
#  'qasigiannguit',
#  'muros',
#  'noshiro',
#  'ostrovnoy',
#  'snezhnogorsk',
#  'richards bay',
#  'homer',
#  'prince rupert',
#  'kouango',
#  'alta floresta',
#  'kargat',
#  'posadas',
#  'lemesos',
#  'port macquarie',
#  'singkawang',
#  'nerchinsk',
#  'nelson bay',
#  'urfa',
#  'adrar',
#  'srednekolymsk',
#  'qujing',
#  'praia',
#  'portland',
#  'rungata',
#  'fevralsk',
#  'puerto carreno',
#  'kaihua',
#  'birjand',
#  'dordrecht',
#  'teluk nibung',
#  'hay river',
#  'azimur',
#  'minot',
#  'heinola',
#  'shahreza',
#  'dipkarpaz',
#  'syntul',
#  'zeya',
#  'barao de melgaco',
#  'yichang',
#  'hinton',
#  'elko',
#  'garden city',
#  'tomatlan',
#  'asayita',
#  'cherskiy',
#  'majene',
#  'ancud',
#  'askarovo',
#  'ciudad bolivar',
#  'jambi',
#  'voh',
#  'barawe',
#  'ajdabiya',
#  'licheng',
#  'ishigaki']

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather", "0"]["description"]

        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    #If an error is experienced, skip the city.
    except: 
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 2 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 3 of Set 1 | quatre cocos
# City not found. Skipping...
# Processing Record 4 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 5 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 7 of Set 1 | ballina
# City not found. Skipping...
# Processing Record 8 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 9 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 10 of Set 1 | honningsvag
# City not found. Skipping...
# Processing Record 11 of Set 1 | nalut
# City not found. Skipping...
# Processing Record 12 of Set 1 | bredasdorp
# City not found. Skipping...
# Processing Record 13 of Set 1 | deputatskiy
# City not found. Skipping...
# Processing Record 14 of Set 1 | hualmay
# City not found. Skipping...
# Processing Record 15 of Set 1 | lewisburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | port elizabeth
# City not found. Skipping...
# Processing Record 17 of Set 1 | albany
# City not found. Skipping...
# Processing Record 18 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 19 of Set 1 | grindavik
# City not found. Skipping...
# Processing Record 20 of Set 1 | castro
# City not found. Skipping...
# Processing Record 21 of Set 1 | juba
# City not found. Skipping...
# Processing Record 22 of Set 1 | pecos
# City not found. Skipping...
# Processing Record 23 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 24 of Set 1 | abu dhabi
# City not found. Skipping...
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | santa maria
# City not found. Skipping...
# Processing Record 27 of Set 1 | porto novo
# City not found. Skipping...
# Processing Record 28 of Set 1 | kodiak
# City not found. Skipping...
# Processing Record 29 of Set 1 | port blair
# City not found. Skipping...
# Processing Record 30 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 31 of Set 1 | kloulklubed
# City not found. Skipping...
# Processing Record 32 of Set 1 | karasburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | port-gentil
# City not found. Skipping...
# Processing Record 34 of Set 1 | kamaishi
# City not found. Skipping...
# Processing Record 35 of Set 1 | amnat charoen
# City not found. Skipping...
# Processing Record 36 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 37 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 38 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 39 of Set 1 | meulaboh
# City not found. Skipping...
# Processing Record 40 of Set 1 | puerto quijarro
# City not found. Skipping...
# Processing Record 41 of Set 1 | sept-iles
# City not found. Skipping...
# Processing Record 42 of Set 1 | gusau
# City not found. Skipping...
# Processing Record 43 of Set 1 | busselton
# City not found. Skipping...
# Processing Record
| tuktoyaktuk
# City not found. Skipping...
# Processing Record 47 of Set 3 | olafsvik
# City not found. Skipping...
# Processing Record 48 of Set 3 | constitucion
# City not found. Skipping...
# Processing Record 49 of Set 3 | severo-kurilsk
# City not found. Skipping...
# Processing Record 50 of Set 3 | atoyatempan
# City not found. Skipping...
# Processing Record 1 of Set 4 | zyryanka
# City not found. Skipping...
# Processing Record 2 of Set 4 | grong
# City not found. Skipping...
# Processing Record 3 of Set 4 | kluang
# City not found. Skipping...
# Processing Record 4 of Set 4 | port keats
# City not found. Skipping...
# Processing Record 5 of Set 4 | jiangyan
# City not found. Skipping...
# Processing Record 6 of Set 4 | lake cowichan
# City not found. Skipping...
# Processing Record 7 of Set 4 | chamba
# City not found. Skipping...
# Processing Record 8 of Set 4 | bambous virieux
# City not found. Skipping...
# Processing Record 9 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 4 | longyearbyen
# City not found. Skipping...
# Processing Record 11 of Set 4 | astoria
# City not found. Skipping...
# Processing Record 12 of Set 4 | vastseliina
# City not found. Skipping...
# Processing Record 13 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 14 of Set 4 | mehamn
# City not found. Skipping...
# Processing Record 15 of Set 4 | pemba
# City not found. Skipping...
# Processing Record 16 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 4 | waipawa
# City not found. Skipping...
# Processing Record 18 of Set 4 | harer
# City not found. Skipping...
# Processing Record 19 of Set 4 | tuatapere
# City not found. Skipping...
# Processing Record 20 of Set 4 | seoul
# City not found. Skipping...
# Processing Record 21 of Set 4 | cabedelo
# City not found. Skipping...
# Processing Record 22 of Set 4 | seymchan
# City not found. Skipping...
# Processing Record 23 of Set 4 | new baltimore
# City not found. Skipping...
# Processing Record 24 of Set 4 | verkhnyaya toyma
# City not found. Skipping...
# Processing Record 25 of Set 4 | waldoboro
# City not found. Skipping...
# Processing Record 26 of Set 4 | tasiilaq
# City not found. Skipping...
# Processing Record 27 of Set 4 | provideniya
# City not found. Skipping...
# Processing Record 28 of Set 4 | bor
# City not found. Skipping...
# Processing Record 29 of Set 4 | itacoatiara
# City not found. Skipping...
# Processing Record 30 of Set 4 | narsaq
# City not found. Skipping...
# Processing Record 31 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 32 of Set 4 | vila
# City not found. Skipping...
# Processing Record 33 of Set 4 | caravelas
# City not found. Skipping...
# Processing Record 34 of Set 4 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 4 | smithers
# City not found. Skipping...
# Processing Record 36 of Set 4 | kailua
# City not found. Skipping...
# Processing Record 37 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 4 | atuona
# City not found. Skipping...
# Processing Record 39 of Set 4 | adamas
# City not found. Skipping...
# Processing Record 40 of Set 4 | makakilo city
# City not found. Skipping...
# Processing Record 41 of Set 4 | padang
# City not found. Skipping...
# Processing Record 42 of Set 4 | hambantota
# City not found. Skipping...
# Processing Record 43 of Set 4 | palana
# City not found. Skipping...
# Processing Record 44 of Set 4 | yumen
# City not found. Skipping...
# Processing Record 45 of Set 4 | wanning
# City not found. Skipping...
# Processing Record 46 of Set 4 | carnarvon
# City not found. Skipping...
# Processing Record 47 of Set 4 | znamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | grenada
# City not found. Skipping...
# Processing Record 49 of Set 4 | lagoa
# City not found. Skipping...
# Processing Record 50 of Set 4 | sabang
# City not found. Skipping...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 13>()
#      17     set_count += 1
#      18     record_count = 1
# ---> 19     time.sleep(60)
#      21 #Create endpoint URL with each city.
#      22 city_url = url + "&q=" + city.replace(" ","+")
#
# KeyboardInterrupt:

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df

# %%
#Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
