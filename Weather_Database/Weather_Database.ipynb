# %%
#Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size = 2000)
lat_lngs = zip(lats, lngs)

# %%
#Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the cities
cities = []

#Identify the nearest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then add it to the list
    if city not in cities:
        cities.append(city)

# %%
#Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in the list.
for i, city in enumerate(cities):

    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Add 1 to the record count.
    record_count += 1
    
    try:
        #Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        #Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        #Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
    
    #If an error is experienced, skip the city.
    except: 
        print("City not found. Skipping...")
        pass
        
#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | sur
# Processing Record 7 of Set 1 | kroya
# Processing Record 8 of Set 1 | aleksandrov gay
# Processing Record 9 of Set 1 | guerrero negro
# Processing Record 10 of Set 1 | bluff
# Processing Record 11 of Set 1 | berlevag
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | carnarvon
# Processing Record 17 of Set 1 | pandan
# Processing Record 18 of Set 1 | lusambo
# Processing Record 19 of Set 1 | banda aceh
# Processing Record 20 of Set 1 | alofi
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | pangnirtung
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | constitucion
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | katherine
# Processing Record 31 of Set 1 | ust-nera
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | nchelenge
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | georgetown
# Processing Record 39 of Set 1 | nuuk
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | los llanos de aridane
# Processing Record 42 of Set 1 | haines junction
# Processing Record 43 of Set 1 | clinton
# Processing Record 44 of Set 1 | pavino
# Processing Record 45 of Set 1 | aklavik
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | ponta delgada
# Processing Record 48 of Set 1 | qaanaaq
# Processing Record 49 of Set 1 | praia
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | arlit
# Processing Record 2 of Set 2 | bima
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | togur
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | dabakala
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | ambarnath
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | totesti
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | labuhan
# Processing Record 16 of Set 2 | terrace bay
# Processing Record 17 of Set 2 | vila velha
# Processing Record 18 of Set 2 | betanzos
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | port lincoln
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | havelock
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | dongning
# Processing Record 29 of Set 2 | waiouru
# Processing Record 30 of Set 2 | ulaangom
# Processing Record 31 of Set 2 | emba
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | grand gaube
# Processing Record 34 of Set 2 | miyazu
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | malindi
# Processing Record 38 of Set 2 | tilichiki
# Processing Record 39 of Set 2 | thinadhoo
# Processing Record 40 of Set 2 | lethem
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | kampot
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | christiana
# Processing Record 45 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 2 | beira
# Processing Record 47 of Set 2 | pevek
# Processing Record 48 of Set 2 | kitimat
# Processing Record 49 of Set 2 | zabol
# Processing Record 50 of Set 2 | victoria
# Processing Record 1 of Set 3 | saldanha
# Processing Record 2 of Set 3 | mikhaylovka
# Processing Record 3 of Set 3 | salalah
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | fukue
# Processing Record 7 of Set 3 | porto novo
# Processing Record 8 of Set 3 | anadyr
# Processing Record 9 of Set 3 | bukama
# Processing Record 10 of Set 3 | tainan
# Processing Record 11 of Set 3 | upernavik
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | tungi
# Processing Record 15 of Set 3 | bauchi
# Processing Record 16 of Set 3 | arraial do cabo
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | nsanje
# Processing Record 19 of Set 3 | petawawa
# Processing Record 20 of Set 3 | mahenge
# Processing Record 21 of Set 3 | port elizabeth
# Processing Record 22 of Set 3 | karratha
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | monte alto
# Processing Record 26 of Set 3 | luau
# Processing Record 27 of Set 3 | ostrovnoy
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | caravelas
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | shumskiy
# Processing Record 32 of Set 3 | marzuq
# Processing Record 33 of Set 3 | bahadurganj
# Processing Record 34 of Set 3 | benghazi
# Processing Record 35 of Set 3 | zaraza
# Processing Record 36 of Set 3 | inhambane
# Processing Record 37 of Set 3 | brae
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | uvinza
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | wuda
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | marneuli
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | kavieng
# Processing Record 47 of Set 3 | hovd
# Processing Record 48 of Set 3 | saskylakh
# Processing Record 49 of Set 3 | sechelt
# Processing Record 50 of Set 3 | atlantic city
# Processing Record 1 of Set 4 | gedo
# Processing Record 2 of Set 4 | bilma
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | iqaluit
# Processing Record 5 of Set 4 | shelburne
# Processing Record 6 of Set 4 | coracora
# Processing Record 7 of Set 4 | provideniya
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | kruisfontein
# Processing Record 11 of Set 4 | north bend
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | bonavista
# Processing Record 14 of Set 4 | buraydah
# Processing Record 15 of Set 4 | biltine
# Processing Record 16 of Set 4 | calama
# Processing Record 17 of Set 4 | pangkalanbuun
# Processing Record 18 of Set 4 | urulga
# City not found. Skipping...
# Processing Record 19 of Set 4 | san policarpo
# Processing Record 20 of Set 4 | nouadhibou
# Processing Record 21 of Set 4 | high rock
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | ulladulla
# Processing Record 24 of Set 4 | tshikapa
# Processing Record 25 of Set 4 | merauke
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 4 | lakes entrance
# Processing Record 30 of Set 4 | cedar falls
# Processing Record 31 of Set 4 | chiredzi
# Processing Record 32 of Set 4 | lagoa
# Processing Record 33 of Set 4 | kavaratti
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | hammerfest
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | amuntai
# Processing Record 38 of Set 4 | harigue
# City not found. Skipping...
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | arica
# Processing Record 41 of Set 4 | kabalo
# Processing Record 42 of Set 4 | dzaoudzi
# Processing Record 43 of Set 4 | benguela
# Processing Record 44 of Set 4 | copperas cove
# Processing Record 45 of Set 4 | lircay
# Processing Record 46 of Set 4 | mendi
# Processing Record 47 of Set 4 | maragogi
# Processing Record 48 of Set 4 | yingkou
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 50 of Set 4 | placerville
# Processing Record 1 of Set 5 | birin
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | nanortalik
# Processing Record 4 of Set 5 | anzio
# Processing Record 5 of Set 5 | oistins
# Processing Record 6 of Set 5 | tyler
# Processing Record 7 of Set 5 | kieta
# Processing Record 8 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | marawi
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | mogadishu
# Processing Record 14 of Set 5 | preeceville
# Processing Record 15 of Set 5 | arrecife
# Processing Record 16 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 5 | uglovoye
# Processing Record 18 of Set 5 | mount gambier
# Processing Record 19 of Set 5 | ancud
# Processing Record 20 of Set 5 | vestmannaeyjar
# Processing Record 21 of Set 5 | niksic
# Processing Record 22 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 5 | soderhamn
# Processing Record 24 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 5 | lima
# Processing Record 26 of Set 5 | saint-philippe
# Processing Record 27 of Set 5 | flin flon
# Processing Record 28 of Set 5 | grindavik
# Processing Record 29 of Set 5 | kedougou
# Processing Record 30 of Set 5 | kupino
# Processing Record 31 of Set 5 | saint-pierre
# Processing Record 32 of Set 5 | mulege
# Processing Record 33 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 5 | qasigiannguit
# Processing Record 35 of Set 5 | puyang
# Processing Record 36 of Set 5 | arcata
# Processing Record 37 of Set 5 | atar
# Processing Record 38 of Set 5 | candido mendes
# Processing Record 39 of Set 5 | richha
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | florianopolis
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | boyolangu
# Processing Record 45 of Set 5 | bucerias
# Processing Record 46 of Set 5 | roald
# Processing Record 47 of Set 5 | muyezerskiy
# Processing Record 48 of Set 5 | yellowknife
# Processing Record 49 of Set 5 | adeje
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 6 | inverell
# Processing Record 3 of Set 6 | abha
# Processing Record 4 of Set 6 | trairi
# Processing Record 5 of Set 6 | worland
# Processing Record 6 of Set 6 | isangel
# Processing Record 7 of Set 6 | bronte
# Processing Record 8 of Set 6 | massape
# Processing Record 9 of Set 6 | durango
# Processing Record 10 of Set 6 | henties bay
# Processing Record 11 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 6 | katobu
# Processing Record 13 of Set 6 | chokurdakh
# Processing Record 14 of Set 6 | hwange
# Processing Record 15 of Set 6 | gwadar
# Processing Record 16 of Set 6 | copiapo
# Processing Record 17 of Set 6 | zatoka
# Processing Record 18 of Set 6 | san quintin
# Processing Record 19 of Set 6 | hamada
# Processing Record 20 of Set 6 | kahului
# Processing Record 21 of Set 6 | poum
# Processing Record 22 of Set 6 | asau
# Processing Record 23 of Set 6 | guangyuan
# Processing Record 24 of Set 6 | vanderbijlpark
# Processing Record 25 of Set 6 | turinsk
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | cetatea de balta
# City not found. Skipping...
# Processing Record 28 of Set 6 | borskoye
# Processing Record 29 of Set 6 | ambon
# Processing Record 30 of Set 6 | dunda
# Processing Record 31 of Set 6 | alta floresta
# Processing Record 32 of Set 6 | gamba
# Processing Record 33 of Set 6 | jumla
# Processing Record 34 of Set 6 | cayenne
# Processing Record 35 of Set 6 | tigil
# Processing Record 36 of Set 6 | oranjemund
# Processing Record 37 of Set 6 | zhigalovo
# Processing Record 38 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 6 | zhangjiakou
# Processing Record 40 of Set 6 | lasa
# Processing Record 41 of Set 6 | mongo
# Processing Record 42 of Set 6 | matamoros
# Processing Record 43 of Set 6 | san andres
# Processing Record 44 of Set 6 | roma
# Processing Record 45 of Set 6 | malanje
# Processing Record 46 of Set 6 | belaya gora
# Processing Record 47 of Set 6 | kondinskoye
# Processing Record 48 of Set 6 | esperance
# Processing Record 49 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 50 of Set 6 | trelew
# Processing Record 1 of Set 7 | zhucheng
# Processing Record 2 of Set 7 | codrington
# Processing Record 3 of Set 7 | chusovoy
# Processing Record 4 of Set 7 | qaqortoq
# Processing Record 5 of Set 7 | miyako
# Processing Record 6 of Set 7 | pervomayskiy
# Processing Record 7 of Set 7 | fare
# Processing Record 8 of Set 7 | fort-shevchenko
# Processing Record 9 of Set 7 | mandapeta
# Processing Record 10 of Set 7 | la reforma
# Processing Record 11 of Set 7 | vanavara
# Processing Record 12 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 7 | thohoyandou
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | deputatskiy
# Processing Record 16 of Set 7 | leh
# Processing Record 17 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 7 | barra
# Processing Record 19 of Set 7 | kalabo
# Processing Record 20 of Set 7 | lavumisa
# Processing Record 21 of Set 7 | neuquen
# Processing Record 22 of Set 7 | tayga
# Processing Record 23 of Set 7 | auki
# Processing Record 24 of Set 7 | san luis
# Processing Record 25 of Set 7 | kemijarvi
# Processing Record 26 of Set 7 | bubaque
# Processing Record 27 of Set 7 | tandalti
# Processing Record 28 of Set 7 | sturgeon bay
# Processing Record 29 of Set 7 | kilindoni
# Processing Record 30 of Set 7 | quesnel
# Processing Record 31 of Set 7 | bathsheba
# Processing Record 32 of Set 7 | hameenlinna
# Processing Record 33 of Set 7 | kyshtovka
# Processing Record 34 of Set 7 | saint anthony
# Processing Record 35 of Set 7 | rio gallegos
# Processing Record 36 of Set 7 | hobyo
# Processing Record 37 of Set 7 | oyama
# Processing Record 38 of Set 7 | forestville
# Processing Record 39 of Set 7 | codo
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 7 | rabo de peixe
# Processing Record 43 of Set 7 | kiruna
# Processing Record 44 of Set 7 | seoul
# Processing Record 45 of Set 7 | burgeo
# Processing Record 46 of Set 7 | camocim
# Processing Record 47 of Set 7 | geraldton
# Processing Record 48 of Set 7 | liuhe
# Processing Record 49 of Set 7 | acajutla
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | cabo san lucas
# Processing Record 3 of Set 8 | pochutla
# Processing Record 4 of Set 8 | amga
# Processing Record 5 of Set 8 | naze
# Processing Record 6 of Set 8 | harper
# Processing Record 7 of Set 8 | okha
# Processing Record 8 of Set 8 | mangan
# Processing Record 9 of Set 8 | edd
# Processing Record 10 of Set 8 | baker city
# Processing Record 11 of Set 8 | bengkulu
# Processing Record 12 of Set 8 | hollins
# Processing Record 13 of Set 8 | upington
# Processing Record 14 of Set 8 | avera
# Processing Record 15 of Set 8 | krasnaya gora
# Processing Record 16 of Set 8 | lubango
# Processing Record 17 of Set 8 | ahipara
# Processing Record 18 of Set 8 | axim
# Processing Record 19 of Set 8 | touros
# Processing Record 20 of Set 8 | songadh
# Processing Record 21 of Set 8 | kutum
# Processing Record 22 of Set 8 | flores da cunha
# Processing Record 23 of Set 8 | plouzane
# Processing Record 24 of Set 8 | uyovu
# Processing Record 25 of Set 8 | birao
# Processing Record 26 of Set 8 | borama
# City not found. Skipping...
# Processing Record 27 of Set 8 | gouyave
# Processing Record 28 of Set 8 | alice springs
# Processing Record 29 of Set 8 | kailua
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | cefalu
# Processing Record 32 of Set 8 | hofn
# Processing Record 33 of Set 8 | vao
# Processing Record 34 of Set 8 | sobolevo
# Processing Record 35 of Set 8 | ashland
# Processing Record 36 of Set 8 | marsh harbour
# Processing Record 37 of Set 8 | melville
# Processing Record 38 of Set 8 | snezhnogorsk
# Processing Record 39 of Set 8 | viedma
# Processing Record 40 of Set 8 | shahreza
# Processing Record 41 of Set 8 | college
# Processing Record 42 of Set 8 | chapada dos guimaraes
# Processing Record 43 of Set 8 | pacific grove
# Processing Record 44 of Set 8 | mazara del vallo
# Processing Record 45 of Set 8 | hasaki
# Processing Record 46 of Set 8 | lazaro cardenas
# Processing Record 47 of Set 8 | sao miguel do araguaia
# Processing Record 48 of Set 8 | horqueta
# Processing Record 49 of Set 8 | olafsvik
# Processing Record 50 of Set 8 | port angeles
# Processing Record 1 of Set 9 | alibag
# Processing Record 2 of Set 9 | waipawa
# Processing Record 3 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 9 | gizo
# Processing Record 5 of Set 9 | hirara
# Processing Record 6 of Set 9 | yerbogachen
# Processing Record 7 of Set 9 | jacqueville
# Processing Record 8 of Set 9 | tukrah
# Processing Record 9 of Set 9 | san patricio
# Processing Record 10 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 9 | shakawe
# Processing Record 12 of Set 9 | ixtapa
# Processing Record 13 of Set 9 | thomastown
# Processing Record 14 of Set 9 | bolivar
# Processing Record 15 of Set 9 | belyy yar
# Processing Record 16 of Set 9 | kontagora
# Processing Record 17 of Set 9 | tayturka
# Processing Record 18 of Set 9 | sola
# Processing Record 19 of Set 9 | souillac
# Processing Record 20 of Set 9 | sept-iles
# Processing Record 21 of Set 9 | oulainen
# Processing Record 22 of Set 9 | tabuk
# Processing Record 23 of Set 9 | kaohsiung
# Processing Record 24 of Set 9 | charlottesville
# Processing Record 25 of Set 9 | khani
# Processing Record 26 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 9 | faya
# Processing Record 28 of Set 9 | ambulu
# Processing Record 29 of Set 9 | boa vista
# Processing Record 30 of Set 9 | panukulan
# Processing Record 31 of Set 9 | havre-saint-pierre
# Processing Record 32 of Set 9 | lushunkou
# City not found. Skipping...
# Processing Record 33 of Set 9 | svetlyy
# Processing Record 34 of Set 9 | cherskiy
# Processing Record 35 of Set 9 | tsumeb
# Processing Record 36 of Set 9 | port hueneme
# Processing Record 37 of Set 9 | ergani
# Processing Record 38 of Set 9 | yuci
# Processing Record 39 of Set 9 | matagami
# Processing Record 40 of Set 9 | clyde river
# Processing Record 41 of Set 9 | tiarei
# Processing Record 42 of Set 9 | te anau
# Processing Record 43 of Set 9 | broome
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | marinette
# Processing Record 46 of Set 9 | valley stream
# Processing Record 47 of Set 9 | naantali
# Processing Record 48 of Set 9 | khromtau
# Processing Record 49 of Set 9 | okhotsk
# Processing Record 50 of Set 9 | mana
# Processing Record 1 of Set 10 | berdigestyakh
# Processing Record 2 of Set 10 | armacao de pera
# Processing Record 3 of Set 10 | tadine
# Processing Record 4 of Set 10 | piopio
# Processing Record 5 of Set 10 | douglas
# Processing Record 6 of Set 10 | timizart
# Processing Record 7 of Set 10 | sisimiut
# Processing Record 8 of Set 10 | abalak
# Processing Record 9 of Set 10 | banikoara
# Processing Record 10 of Set 10 | parkes
# Processing Record 11 of Set 10 | dunedin
# Processing Record 12 of Set 10 | fort nelson
# Processing Record 13 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 10 | kyrylivka
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | inuvik
# Processing Record 17 of Set 10 | ossora
# Processing Record 18 of Set 10 | taltal
# Processing Record 19 of Set 10 | rocha
# Processing Record 20 of Set 10 | marang
# Processing Record 21 of Set 10 | yuzhno-kurilsk
# Processing Record 22 of Set 10 | victoria point
# Processing Record 23 of Set 10 | kenai
# Processing Record 24 of Set 10 | chibuto
# Processing Record 25 of Set 10 | grua
# Processing Record 26 of Set 10 | chippewa falls
# Processing Record 27 of Set 10 | neiafu
# Processing Record 28 of Set 10 | micheweni
# Processing Record 29 of Set 10 | nova olinda do norte
# Processing Record 30 of Set 10 | cap malheureux
# Processing Record 31 of Set 10 | itarema
# Processing Record 32 of Set 10 | japura
# Processing Record 33 of Set 10 | devils lake
# Processing Record 34 of Set 10 | saurimo
# Processing Record 35 of Set 10 | urdoma
# Processing Record 36 of Set 10 | volkach
# Processing Record 37 of Set 10 | anloga
# Processing Record 38 of Set 10 | westport
# Processing Record 39 of Set 10 | rio branco do sul
# Processing Record 40 of Set 10 | acarau
# Processing Record 41 of Set 10 | dongsheng
# Processing Record 42 of Set 10 | yerazgavors
# Processing Record 43 of Set 10 | kudymkar
# Processing Record 44 of Set 10 | sao paulo de olivenca
# Processing Record 45 of Set 10 | bilibino
# Processing Record 46 of Set 10 | hay river
# Processing Record 47 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | nador
# Processing Record 49 of Set 10 | nishihara
# Processing Record 50 of Set 10 | port hedland
# Processing Record 1 of Set 11 | san miguel
# Processing Record 2 of Set 11 | mitsamiouli
# Processing Record 3 of Set 11 | owando
# Processing Record 4 of Set 11 | praia da vitoria
# Processing Record 5 of Set 11 | zielona gora
# Processing Record 6 of Set 11 | beian
# Processing Record 7 of Set 11 | sorland
# Processing Record 8 of Set 11 | husavik
# Processing Record 9 of Set 11 | lata
# Processing Record 10 of Set 11 | klaksvik
# Processing Record 11 of Set 11 | sankeshwar
# Processing Record 12 of Set 11 | brandon
# Processing Record 13 of Set 11 | la rioja
# Processing Record 14 of Set 11 | mikhaylovskoye
# Processing Record 15 of Set 11 | meulaboh
# Processing Record 16 of Set 11 | huarmey
# Processing Record 17 of Set 11 | estepona
# Processing Record 18 of Set 11 | khandyga
# Processing Record 19 of Set 11 | arawa
# Processing Record 20 of Set 11 | umm lajj
# Processing Record 21 of Set 11 | boueni
# Processing Record 22 of Set 11 | moose factory
# Processing Record 23 of Set 11 | iranshahr
# Processing Record 24 of Set 11 | yumen
# Processing Record 25 of Set 11 | ciudad bolivar
# Processing Record 26 of Set 11 | nhamunda
# Processing Record 27 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 11 | pedernales
# Processing Record 29 of Set 11 | saint-augustin
# Processing Record 30 of Set 11 | the valley
# Processing Record 31 of Set 11 | komsomolskiy
# Processing Record 32 of Set 11 | camacha
# Processing Record 33 of Set 11 | praya
# Processing Record 34 of Set 11 | el carmen
# Processing Record 35 of Set 11 | mayumba
# Processing Record 36 of Set 11 | kaeo
# Processing Record 37 of Set 11 | araioses
# Processing Record 38 of Set 11 | puerto maldonado
# Processing Record 39 of Set 11 | zhangye
# Processing Record 40 of Set 11 | mamallapuram
# Processing Record 41 of Set 11 | belmonte
# Processing Record 42 of Set 11 | nichinan
# Processing Record 43 of Set 11 | san vicente
# Processing Record 44 of Set 11 | panaba
# Processing Record 45 of Set 11 | novobiryusinskiy
# Processing Record 46 of Set 11 | kandrian
# Processing Record 47 of Set 11 | znamenskoye
# Processing Record 48 of Set 11 | taldan
# Processing Record 49 of Set 11 | camana
# Processing Record 50 of Set 11 | ambilobe
# Processing Record 1 of Set 12 | tucumcari
# Processing Record 2 of Set 12 | almeria
# Processing Record 3 of Set 12 | colares
# Processing Record 4 of Set 12 | rongcheng
# Processing Record 5 of Set 12 | hirado
# Processing Record 6 of Set 12 | pacaembu
# Processing Record 7 of Set 12 | curvelo
# Processing Record 8 of Set 12 | pitsunda
# Processing Record 9 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 12 | muisne
# Processing Record 11 of Set 12 | aracati
# Processing Record 12 of Set 12 | uvarovo
# Processing Record 13 of Set 12 | portland
# Processing Record 14 of Set 12 | takestan
# Processing Record 15 of Set 12 | marigot
# Processing Record 16 of Set 12 | iskateley
# Processing Record 17 of Set 12 | kingsport
# Processing Record 18 of Set 12 | muros
# Processing Record 19 of Set 12 | brazzaville
# Processing Record 20 of Set 12 | patitirion
# Processing Record 21 of Set 12 | sedan
# Processing Record 22 of Set 12 | betsiamites
# Processing Record 23 of Set 12 | umba
# Processing Record 24 of Set 12 | verkhnevilyuysk
# Processing Record 25 of Set 12 | wladyslawowo
# Processing Record 26 of Set 12 | mecca
# Processing Record 27 of Set 12 | lompoc
# Processing Record 28 of Set 12 | angoche
# Processing Record 29 of Set 12 | mareeba
# Processing Record 30 of Set 12 | boca del rio
# Processing Record 31 of Set 12 | culpeper
# Processing Record 32 of Set 12 | pauini
# Processing Record 33 of Set 12 | la gomera
# Processing Record 34 of Set 12 | half moon bay
# Processing Record 35 of Set 12 | phan thiet
# Processing Record 36 of Set 12 | sistranda
# Processing Record 37 of Set 12 | dyadkovskaya
# City not found. Skipping...
# Processing Record 38 of Set 12 | cukai
# Processing Record 39 of Set 12 | shintomi
# Processing Record 40 of Set 12 | waspan
# Processing Record 41 of Set 12 | mount isa
# Processing Record 42 of Set 12 | filadelfia
# Processing Record 43 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 12 | harstad
# Processing Record 45 of Set 12 | ketchikan
# Processing Record 46 of Set 12 | jiuquan
# Processing Record 47 of Set 12 | halifax
# Processing Record 48 of Set 12 | trincomalee
# Processing Record 49 of Set 12 | isla mujeres
# Processing Record 50 of Set 12 | valday
# Processing Record 1 of Set 13 | south venice
# Processing Record 2 of Set 13 | port augusta
# Processing Record 3 of Set 13 | harnoli
# Processing Record 4 of Set 13 | nabire
# Processing Record 5 of Set 13 | general roca
# Processing Record 6 of Set 13 | sechura
# Processing Record 7 of Set 13 | peniche
# Processing Record 8 of Set 13 | chimbote
# Processing Record 9 of Set 13 | orlik
# Processing Record 10 of Set 13 | orapa
# Processing Record 11 of Set 13 | murgab
# Processing Record 12 of Set 13 | andenes
# Processing Record 13 of Set 13 | moron
# Processing Record 14 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 13 | tezu
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | augusto correa
# Processing Record 18 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 13 | sao jose da coroa grande
# Processing Record 20 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 21 of Set 13 | wewak
# Processing Record 22 of Set 13 | coos bay
# Processing Record 23 of Set 13 | shingu
# Processing Record 24 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 25 of Set 13 | worthington
# Processing Record 26 of Set 13 | pospelikha
# Processing Record 27 of Set 13 | vostok
# Processing Record 28 of Set 13 | genhe
# Processing Record 29 of Set 13 | ewa beach
# Processing Record 30 of Set 13 | hervey bay
# Processing Record 31 of Set 13 | rawson
# Processing Record 32 of Set 13 | paciran
# Processing Record 33 of Set 13 | jipijapa
# Processing Record 34 of Set 13 | redondela
# Processing Record 35 of Set 13 | liniere
# City not found. Skipping...
# Processing Record 36 of Set 13 | zhezkazgan
# Processing Record 37 of Set 13 | taybad
# Processing Record 38 of Set 13 | san jeronimo
# Processing Record 39 of Set 13 | gorom-gorom
# Processing Record 40 of Set 13 | puerto escondido
# Processing Record 41 of Set 13 | pleasanton
# Processing Record 42 of Set 13 | mataram
# Processing Record 43 of Set 13 | makat
# Processing Record 44 of Set 13 | joshimath
# Processing Record 45 of Set 13 | topi
# Processing Record 46 of Set 13 | oudtshoorn
# Processing Record 47 of Set 13 | kurilsk
# Processing Record 48 of Set 13 | isla vista
# Processing Record 49 of Set 13 | brindisi
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | alyangula
# Processing Record 2 of Set 14 | nagapattinam
# Processing Record 3 of Set 14 | fuyang
# Processing Record 4 of Set 14 | ust-maya
# Processing Record 5 of Set 14 | krasnoarmeysk
# Processing Record 6 of Set 14 | antofagasta
# Processing Record 7 of Set 14 | tazovskiy
# Processing Record 8 of Set 14 | ostersund
# Processing Record 9 of Set 14 | lalmohan
# Processing Record 10 of Set 14 | limbang
# Processing Record 11 of Set 14 | maceio
# Processing Record 12 of Set 14 | kuytun
# Processing Record 13 of Set 14 | itoman
# Processing Record 14 of Set 14 | tereze
# Processing Record 15 of Set 14 | bantou
# Processing Record 16 of Set 14 | tuatapere
# Processing Record 17 of Set 14 | chakia
# Processing Record 18 of Set 14 | woodbury
# Processing Record 19 of Set 14 | vsetaty
# Processing Record 20 of Set 14 | banamba
# Processing Record 21 of Set 14 | northam
# Processing Record 22 of Set 14 | nara
# Processing Record 23 of Set 14 | ibra
# Processing Record 24 of Set 14 | watsa
# Processing Record 25 of Set 14 | hambantota
# Processing Record 26 of Set 14 | tari
# Processing Record 27 of Set 14 | peleduy
# Processing Record 28 of Set 14 | chemnitz
# Processing Record 29 of Set 14 | gao
# Processing Record 30 of Set 14 | tabou
# Processing Record 31 of Set 14 | buloh kasap
# Processing Record 32 of Set 14 | north platte
# Processing Record 33 of Set 14 | aksu
# Processing Record 34 of Set 14 | mulki
# Processing Record 35 of Set 14 | forio
# Processing Record 36 of Set 14 | abu kamal
# Processing Record 37 of Set 14 | bhatkal
# Processing Record 38 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 14 | inongo
# Processing Record 40 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 14 | pisco
# Processing Record 42 of Set 14 | naica
# Processing Record 43 of Set 14 | rudnichnyy
# Processing Record 44 of Set 14 | udachnyy
# Processing Record 45 of Set 14 | eenhana
# Processing Record 46 of Set 14 | pasni
# Processing Record 47 of Set 14 | surdulica
# Processing Record 48 of Set 14 | hengshui
# Processing Record 49 of Set 14 | sinnamary
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | dundwaraganj
# Processing Record 2 of Set 15 | bay roberts
# Processing Record 3 of Set 15 | aksarka
# Processing Record 4 of Set 15 | preston
# Processing Record 5 of Set 15 | muzaffarpur
# Processing Record 6 of Set 15 | sao jose dos campos
# Processing Record 7 of Set 15 | pedro betancourt
# Processing Record 8 of Set 15 | tibati
# Processing Record 9 of Set 15 | kohima
# Processing Record 10 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 11 of Set 15 | sayat
# Processing Record 12 of Set 15 | chingirlau
# Processing Record 13 of Set 15 | pemangkat
# Processing Record 14 of Set 15 | vallenar
# Processing Record 15 of Set 15 | aitape
# Processing Record 16 of Set 15 | juneau
# Processing Record 17 of Set 15 | plainview
# Processing Record 18 of Set 15 | hebi
# Processing Record 19 of Set 15 | yablonovo
# Processing Record 20 of Set 15 | stromness
# Processing Record 21 of Set 15 | dalbandin
# Processing Record 22 of Set 15 | saint-louis
# Processing Record 23 of Set 15 | catamarca
# Processing Record 24 of Set 15 | valley city
# Processing Record 25 of Set 15 | potsdam
# Processing Record 26 of Set 15 | nerchinskiy zavod
# Processing Record 27 of Set 15 | nome
# Processing Record 28 of Set 15 | bundaberg
# Processing Record 29 of Set 15 | lerik
# Processing Record 30 of Set 15 | mersing
# Processing Record 31 of Set 15 | liverpool
# Processing Record 32 of Set 15 | dalby
# Processing Record 33 of Set 15 | saint-ambroise
# Processing Record 34 of Set 15 | paamiut
# Processing Record 35 of Set 15 | wagar
# Processing Record 36 of Set 15 | beringovskiy
# Processing Record 37 of Set 15 | obidos
# Processing Record 38 of Set 15 | sapao
# City not found. Skipping...
# Processing Record 39 of Set 15 | vuktyl
# Processing Record 40 of Set 15 | pohrebyshche
# Processing Record 41 of Set 15 | carman
# Processing Record 42 of Set 15 | al
# City not found. Skipping...
# Processing Record 43 of Set 15 | ucluelet
# Processing Record 44 of Set 15 | date
# Processing Record 45 of Set 15 | funtua
# Processing Record 46 of Set 15 | hohhot
# Processing Record 47 of Set 15 | klyuchi
# Processing Record 48 of Set 15 | pyapon
# Processing Record 49 of Set 15 | adrar
# Processing Record 50 of Set 15 | odweyne
# Processing Record 1 of Set 16 | mingshui
# Processing Record 2 of Set 16 | kununurra
# Processing Record 3 of Set 16 | skibbereen
# Processing Record 4 of Set 16 | milkovo
# Processing Record 5 of Set 16 | argalasti
# Processing Record 6 of Set 16 | vitimskiy
# City not found. Skipping...
# Processing Record 7 of Set 16 | penzance
# Processing Record 8 of Set 16 | opobo
# City not found. Skipping...
# Processing Record 9 of Set 16 | vila franca do campo
# Processing Record 10 of Set 16 | hualmay
# Processing Record 11 of Set 16 | altay
# Processing Record 12 of Set 16 | veraval
# Processing Record 13 of Set 16 | labrea
# Processing Record 14 of Set 16 | winnemucca
# Processing Record 15 of Set 16 | betki
# City not found. Skipping...
# Processing Record 16 of Set 16 | gambela
# Processing Record 17 of Set 16 | balkhash
# Processing Record 18 of Set 16 | nouakchott
# Processing Record 19 of Set 16 | upata
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cape Town      ZA -33.9258   18.4232     59.09        83          40
# 1        Avarua      CK -21.2078 -159.7750     78.85        73          40
# 2    Butaritari      KI   3.0707  172.7902     81.70        71          13
# 3        Dikson      RU  73.5069   80.5464     32.50        79         100
# 4           Sur      OM  22.5667   59.5289     83.14        65           6
# ..          ...     ...      ...       ...       ...       ...         ...
# 713  Winnemucca      US  40.9730 -117.7357     87.85         8           0
# 714     Gambela      ET   8.2500   34.5833     69.60        95         100
# 715    Balkhash      KZ  46.8440   74.9804     62.85        41          83
# 716  Nouakchott      MR  18.0858  -15.9785     82.33        81         100
# 717       Upata      VE   8.0086  -62.3989     76.19        96         100
#
#      Wind Speed Current Description
# 0          3.44    scattered clouds
# 1         13.80    scattered clouds
# 2         11.39          few clouds
# 3         16.87     overcast clouds
# 4          8.95           clear sky
# ..          ...                 ...
# 713        4.61           clear sky
# 714        7.18          light rain
# 715        4.74       broken clouds
# 716        6.24          light rain
# 717        3.58     overcast clouds
#
# [718 rows x 9 columns]

# %%
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

#Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
